# %%
from data_loader import SaliencyDataset
train_img = "data/train/images"
train_mask = "data/train_mask/ground_truth_mask"

dataset = SaliencyDataset(train_img, train_mask)

img, mask = dataset[0]
print(img.shape, mask.shape)
# Out:
# torch.Size([3, 128, 128]) torch.Size([1, 128, 128])

# %%
import os

print(os.listdir(train_img)[:5])
print(os.listdir(train_mask)[:5])
# Out:
# ['0001.jpg', '0002.jpg', '0003.jpg', '0004.jpg', '0005.jpg']
# ['0001.png', '0002.png', '0003.png', '0004.png', '0005.png']
